# %% [markdown]
# # 01 Importing Libraries

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 2 Importing Data

# %%
#creating path
path=r'/Users/serenakunzmann/Documents/CareerFoundry-Python/03-2025 Instacart Basket Analysis'

# %%
#importing df_ords_prior
df_ords_prior=pd.read_csv(os.path.join(path,'Data','Original Data','orders_products_prior.csv'))

# %%
#importing df_ords
df_ords=pd.read_csv(os.path.join(path,'Data','Prepared Data','Data Consistency','orders_checked.csv'))

# %%
#checking output
df_ords_prior.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %%
#checking ords output
df_ords.head()
# Out:
#    Unnamed: 0  order_id  user_id  order_number  Order_day_of_week  \
# 0           0   2539329        1             1                  2
# 1           1   2398795        1             2                  3
# 2           2    473747        1             3                  3
# 3           3   2254736        1             4                  4
# 4           4    431534        1             5                  4
#
#    order_hour_of_day  days_since_prior_order
# 0                  8                     NaN
# 1                  7                    15.0
# 2                 12                    21.0
# 3                  7                    29.0
# 4                 15                    28.0

# %%
df_ords_prior.shape
# Out:
# (32434489, 4)

# %%
df_ords.shape
# Out:
# (999999, 7)

# %%
df_merged_large=df_ords.merge(df_ords_prior,on='order_id',indicator=True)

# %%
df_merged_large.head()
# Out:
#    Unnamed: 0  order_id  user_id  order_number  Order_day_of_week  \
# 0           0   2539329        1             1                  2
# 1           0   2539329        1             1                  2
# 2           0   2539329        1             1                  2
# 3           0   2539329        1             1                  2
# 4           0   2539329        1             1                  2
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# 1                  8                     NaN       14084                  2
# 2                  8                     NaN       12427                  3
# 3                  8                     NaN       26088                  4
# 4                  8                     NaN       26405                  5
#
#    reordered _merge
# 0          0   both
# 1          0   both
# 2          0   both
# 3          0   both
# ...

# %%
df_merged_large['_merge'].value_counts()
# Out:
# _merge
# both          9462255
# left_only           0
# right_only          0
# Name: count, dtype: int64

# %%
df_merged_large_2=df_ords.merge(df_ords_prior,on=['order_id'],how ='outer')

# %%
df_merged_large_2
# Out:
#           Unnamed: 0  order_id  user_id  order_number  Order_day_of_week  \
# 0                NaN         2      NaN           NaN                NaN
# 1                NaN         2      NaN           NaN                NaN
# 2                NaN         2      NaN           NaN                NaN
# 3                NaN         2      NaN           NaN                NaN
# 4                NaN         2      NaN           NaN                NaN
# ...              ...       ...      ...           ...                ...
# 32494561    419472.0   3421083  25247.0          24.0                2.0
# 32494562    419472.0   3421083  25247.0          24.0                2.0
# 32494563    419472.0   3421083  25247.0          24.0                2.0
# 32494564    419472.0   3421083  25247.0          24.0                2.0
# 32494565    419472.0   3421083  25247.0          24.0                2.0
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# ...

# %%
df_order_og=pd.read_csv(os.path.join(path,'Data','Original Data','orders.csv'))

# %%
df_order_og.shape
# Out:
# (3421083, 7)

# %%
df_ords.shape
# Out:
# (999999, 7)

# %%
df_order_og.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
df_order_og.describe()
# Out:
#            order_id       user_id  order_number     order_dow  \
# count  3.421083e+06  3.421083e+06  3.421083e+06  3.421083e+06
# mean   1.710542e+06  1.029782e+05  1.715486e+01  2.776219e+00
# std    9.875817e+05  5.953372e+04  1.773316e+01  2.046829e+00
# min    1.000000e+00  1.000000e+00  1.000000e+00  0.000000e+00
# 25%    8.552715e+05  5.139400e+04  5.000000e+00  1.000000e+00
# 50%    1.710542e+06  1.026890e+05  1.100000e+01  3.000000e+00
# 75%    2.565812e+06  1.543850e+05  2.300000e+01  5.000000e+00
# max    3.421083e+06  2.062090e+05  1.000000e+02  6.000000e+00
#
#        order_hour_of_day  days_since_prior_order
# count       3.421083e+06            3.214874e+06
# mean        1.345202e+01            1.111484e+01
# std         4.226088e+00            9.206737e+00
# min         0.000000e+00            0.000000e+00
# 25%         1.000000e+01            4.000000e+00
# 50%         1.300000e+01            7.000000e+00
# 75%         1.600000e+01            1.500000e+01
# ...

# %%
# dropping eval_set from orders.csv
df_order_og.drop(columns=['eval_set'])
# Out:
#          order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0         2539329        1             1          2                  8
# 1         2398795        1             2          3                  7
# 2          473747        1             3          3                 12
# 3         2254736        1             4          4                  7
# 4          431534        1             5          4                 15
# ...           ...      ...           ...        ...                ...
# 3421078   2266710   206209            10          5                 18
# 3421079   1854736   206209            11          4                 10
# 3421080    626363   206209            12          1                 12
# 3421081   2977660   206209            13          1                 12
# 3421082    272231   206209            14          6                 14
#
#          days_since_prior_order
# 0                           NaN
# 1                          15.0
# ...

# %%
df_order_og.rename(columns={'order_dow':'order_day_of_week'},inplace=True)

# %%
df_order_og['order_id'] = df_order_og['order_id'].astype('str')

# %%
df_order_og['user_id'] = df_order_og['user_id'].astype('str')

# %%
df_order_og.to_csv(os.path.join(path,'Data','Prepared Data','Data Consistency','orders_REchecked.csv'))

# %%
df_order=pd.read_csv(os.path.join(path,'Data','Prepared Data','Data Consistency','orders_REchecked.csv'), index_col=False)

# %%
df_order.shape
# Out:
# (3421083, 8)

# %%
df_order.head()
# Out:
#    Unnamed: 0  order_id  user_id eval_set  order_number  order_day_of_week  \
# 0           0   2539329        1    prior             1                  2
# 1           1   2398795        1    prior             2                  3
# 2           2    473747        1    prior             3                  3
# 3           3   2254736        1    prior             4                  4
# 4           4    431534        1    prior             5                  4
#
#    order_hour_of_day  days_since_prior_order
# 0                  8                     NaN
# 1                  7                    15.0
# 2                 12                    21.0
# 3                  7                    29.0
# 4                 15                    28.0

# %%
df_ords=df_ords.drop(columns=['Unnamed: 0'])

# %%
df_orde=df_order.drop(columns=['eval_set'])

# %%
df_ords.describe()
# Out:
#            order_id        user_id   order_number  Order_day_of_week  \
# count  9.999990e+05  999999.000000  999999.000000      999999.000000
# mean   1.711274e+06   30105.433949      17.193345           2.779240
# std    9.876569e+05   17323.577936      17.716800           2.048188
# min    6.000000e+00       1.000000       1.000000           0.000000
# 25%    8.557595e+05   15117.000000       5.000000           1.000000
# 50%    1.711006e+06   30148.000000      11.000000           3.000000
# 75%    2.567507e+06   45132.000000      24.000000           5.000000
# max    3.421083e+06   60078.000000     100.000000           6.000000
#
#        order_hour_of_day  days_since_prior_order
# count      999999.000000           939921.000000
# mean           13.449694               11.097082
# std             4.220945                9.183694
# min             0.000000                0.000000
# 25%            10.000000                4.000000
# ...

# %%
df_ords['order_id'] = df_ords['order_id'].astype('str')

# %%
df_ords['user_id'] = df_ords['user_id'].astype('str')

# %%
df_ords.describe()
# Out:
#         order_number  Order_day_of_week  order_hour_of_day  \
# count  999999.000000      999999.000000      999999.000000
# mean       17.193345           2.779240          13.449694
# std        17.716800           2.048188           4.220945
# min         1.000000           0.000000           0.000000
# 25%         5.000000           1.000000          10.000000
# 50%        11.000000           3.000000          13.000000
# 75%        24.000000           5.000000          16.000000
# max       100.000000           6.000000          23.000000
#
#        days_since_prior_order
# count           939921.000000
# mean                11.097082
# std                  9.183694
# min                  0.000000
# 25%                  4.000000
# 50%                  7.000000
# 75%                 15.000000
# max                 30.000000

# %%
df_ords.to_csv(os.path.join(path,'Data','Prepared Data','Data Consistency','order_checked_again.csv'))

# %%
df_ords.shape
# Out:
# (999999, 6)
