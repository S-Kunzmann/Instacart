# %% [markdown]
# # 01 Importing Libraries

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 02 Importing Data

# %%
#creating path
path=r'/Users/serenakunzmann/Documents/CareerFoundry-Python/03-2025 Instacart Basket Analysis'

# %%
#importing products
df_prods=pd.read_csv(os.path.join(path,'Data','Prepared Data','Data Consistency','products_wrangled.csv'), index_col=False)

# %%
#importing order_order_prior_combined_pickle_file
df_ords_comb=pd.read_pickle(os.path.join(path,'Data','Prepared Data','Data Consistency','order_prods_combined_pkl'))

# %% [markdown]
# Checking shape

# %%
df_prods.shape
# Out:
# (49672, 6)

# %%
df_ords_comb.shape
# Out:
# (32434489, 10)

# %% [markdown]
# # 03 Merging Data

# %%
# test merge without overwriting with merge flag 'match'
pd.merge(df_ords_comb , df_prods , on = ['product_id'] , how = 'inner', indicator = 'match' )
# Out:
#           order_id user_id  order_number  order_day_of_week  \
# 0          2539329       1             1                  2
# 1          2539329       1             1                  2
# 2          2539329       1             1                  2
# 3          2539329       1             1                  2
# 4          2539329       1             1                  2
# ...            ...     ...           ...                ...
# 32404854   2977660  206209            13                  1
# 32404855   2977660  206209            13                  1
# 32404856   2977660  206209            13                  1
# 32404857   2977660  206209            13                  1
# 32404858   2977660  206209            13                  1
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 0                         8                     NaN         196
# 1                         8                     NaN       14084
# ...

# %%
#merging df_prods and df_order_combined on product_id
df_merged_OC_P=df_ords_comb.merge(df_prods, on='product_id', indicator= 'true')

# %%
df_merged_OC_P.head()
# Out:
#    order_id user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329       1             1                  2                  8
# 1   2539329       1             1                  2                  8
# 2   2539329       1             1                  2                  8
# 3   2539329       1             1                  2                  8
# 4   2539329       1             1                  2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0                     NaN         196                  1          0   both
# 1                     NaN       14084                  2          0   both
# 2                     NaN       12427                  3          0   both
# 3                     NaN       26088                  4          0   both
# 4                     NaN       26405                  5          0   both
#
#    Unnamed: 0                             product_name  aisle_id  \
# ...

# %%
df_merged_OC_P.shape
# Out:
# (32404859, 16)

# %%
# droping _merge and Unnamed colums
df_merged_OC_P_3 =df_merged_OC_P_2.drop('Unnamed: 0', axis =1)

# %%
df_merged_OC_P_3.head()
# Out:
#    order_id user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329       1             1                  2                  8
# 1   2539329       1             1                  2                  8
# 2   2539329       1             1                  2                  8
# 3   2539329       1             1                  2                  8
# 4   2539329       1             1                  2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                     NaN       14084                  2          0
# 2                     NaN       12427                  3          0
# 3                     NaN       26088                  4          0
# 4                     NaN       26405                  5          0
#
#                               product_name  aisle_id  department_id  prices  \
# ...

# %%
#exporting Combined Data
df_merged_OC_P_3.to_pickle(os.path.join(path,'Data','Prepared Data','orders_products_merged.pkl'))
