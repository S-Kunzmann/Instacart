# %% [markdown]
# # 01 Importing Libraries

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 02 Importing Data

# %%
# creating path
path= r'/Users/serenakunzmann/Documents/CareerFoundry-Python/03-2025 Instacart Basket Analysis/Data'

# %%
# importing df_ords_prods_merge
df_merge=pd.read_csv(os.path.join(path,'Prepared Data','Data Consistency','ords_prods_merged_clean.csv'))

# %%
# importing df_ords_prods_merge
df_full=pd.read_csv(os.path.join(path,'Prepared Data','Data Consistency','ords_prods_merged_clean.csv'))

# %%
df_merge.head()
# Out:
#    Unnamed: 0  order_id  user_id  order_number  order_day_of_week  \
# 0           0   2539329        1             1                  2
# 1           1   2539329        1             1                  2
# 2           2   2539329        1             1                  2
# 3           3   2539329        1             1                  2
# 4           4   2539329        1             1                  2
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# 1                  8                     NaN       14084                  2
# 2                  8                     NaN       12427                  3
# 3                  8                     NaN       26088                  4
# 4                  8                     NaN       26405                  5
#
#    reordered                             product_name  aisle_id  \
# ...

# %%
df_merge=df_merge.drop(columns=['Unnamed: 0'])

# %%
df_merge.shape
# Out:
# (32404859, 14)

# %% [markdown]
# # 03 Filtering Data on smaller Susbet

# %%
# filtering the first million rows
df=df_merge[:1000000]

# %% [markdown]
# # 04 Creating User-Defined Statement

# %%
# creating price category column
def price_label(row):
    if row['prices']<=5:
        return 'Low-range product'
    elif (row['prices'] >5) and (row ['prices'] <= 15):
        return 'Mid-range product'
    elif row['prices'] > 15:
        return 'High-range product'
    else: return 'Not enough data'

# If the value within the “prices” column within the given row is less than or equal to 5, then return the string “Low-range product.” 
# Or else, if the value within the “prices” column within the given row is greater than 5 and less than or equal to 15, then return the string “Mid-range product.”
# Or else, if the value of the “prices” column within the given row is greater than 15, then return the string “High-range product.”
# Or else, return the string “Not enough data.”

# %%
# applying new column price label to dataframe
df['price_range']=df.apply(price_label,axis=1)
# Out:
# /var/folders/dc/m090wqld5fs_bfy3ppvjgp380000gn/T/ipykernel_37104/2365393589.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range']=df.apply(price_label,axis=1)

# %%
#checking shape
df.shape
# Out:
# (1000000, 14)

# %%
# counting price category values
df['price_range'].value_counts(dropna=False)
# Out:
# price_range
# Mid-range product     673340
# Low-range product     314392
# High-range product     12268
# Name: count, dtype: int64

# %% [markdown]
# # 05 Creating Loc Functions

# %%
#using loc function on subset dataframe
df.loc[df['prices']>15, 'price_range_loc'] = 'High-range product'
# Out:
# /var/folders/dc/m090wqld5fs_bfy3ppvjgp380000gn/T/ipykernel_37104/2579669221.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[df['prices']>15, 'price_range_loc'] = 'High-range product'

# %%
df.loc[(df['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df.loc[df['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
df['price_range_loc'].value_counts(dropna=False)
# Out:
# price_range_loc
# Mid-range product     673340
# Low-range product     314392
# High-range product     12268
# Name: count, dtype: int64

# %%
# creating loc functions on full dataframe
df_full.loc[df_full['prices']>15, 'price_range_loc']='High-range product'

# %%
df_full.loc[(df_full['prices'] <=15) & (df_full['prices'] > 5), 'price_range_loc']='Mid-range product'

# %%
df_full.loc[df_full['prices'] <= 5, 'price_range_loc']='Low-range product'

# %%
df_full['price_range_loc'].value_counts(dropna=False)
# Out:
# price_range_loc
# Mid-range product     21865987
# Low-range product     10126321
# High-range product      412551
# Name: count, dtype: int64

# %% [markdown]
# # 06 Creating For-Loop commands

# %%
#creating new column to summarize how busy each day of the week is
df_full['order_day_of_week'].value_counts(dropna=False)
# Out:
# order_day_of_week
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: count, dtype: int64

# %%
result = []
for value in df_full["order_day_of_week"]:
    if value== 0:
        result.append("Busiest day")
    elif value == 4:
        result.append("least busy")
    else:
        result.append("Regularly busy")

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'least busy',
#  'least busy',
#  'least busy',
#  'least busy',
#  'least busy',
#  'least busy',
#  'least busy',
#  'least busy',
#  'least busy',
#  'least busy',
#  'least busy',
#  'least busy',
#  'least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
# creating a new column for the result categories
df_full['busiest_day'] = result

# %%
df_full['busiest_day'].value_counts(dropna=False)
# Out:
# busiest_day
# Regularly busy    22416875
# Busiest day        6204182
# least busy         3783802
# Name: count, dtype: int64

# %% [markdown]
# # 07 Task

# %%
#Suppose your clients have changed their minds about the labels you created in your “busiest_day” column.
#Now, they want “Busiest day” to become “Busiest days” (plural). This label should correspond with the two busiest days 
#of the week as opposed to the single busiest day. At the same time, they’d also like to know the two slowest days.
#Create a new column for this using a suitable method.

# %%
df_full['order_day_of_week'].value_counts()
# Out:
# order_day_of_week
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: count, dtype: int64

# %%
Observation: the 2 busiest days are saturday & sunday. the 2 slowest days are tuesday & wednesday

# %%
# creating categories
results = []
for value in df_full["order_day_of_week"]:
    if value== 0 or value==2:
        results.append("Busiest days")
    elif value == 4 or value == 3:
        results.append("Slowest days")
    else:
        results.append("Regular days")

# %%
# creating a new column for the new results categories
df_full['busiest_days'] = results

# %%
# checking frequency
df_full['busiest_days'].value_counts(dropna=False)
# Out:
# busiest_days
# Regular days    14362511
# Busiest days    10418012
# Slowest days     7624336
# Name: count, dtype: int64

# %% [markdown]
# Observations: Now we see more orders in busiest and slowest days and less in regular days

# %%
#When too many users make Instacart orders at the same time, the app freezes.
#The senior technical officer at Instacart wants you to identify the busiest hours of the day. 
#Rather than by hour, they want periods of time labeled “Most orders,” “Average orders,” and “Fewest orders.”
#Create a new column containing these labels called “busiest_period_of_day.”

# %%
# checking frequency
df_full['order_hour_of_day'].value_counts(dropna=False)
# Out:
# order_hour_of_day
# 10    2761760
# 11    2736140
# 14    2689136
# 15    2662144
# 13    2660954
# 12    2618532
# 16    2535202
# 9     2454203
# 17    2087654
# 8     1718118
# 18    1636502
# 19    1258305
# 20     976156
# 7      891054
# 21     795637
# 22     634225
# 23     402316
# 6      290493
# 0      218769
# 1      115700
# 5       87961
# 2       69375
# 4       53242
# 3       51281
# Name: count, dtype: int64

# %% [markdown]
# Observations: most orders come in at 10,11,14,15,13,12,16 &9. avg orders come in at 17,8,18,19,20,7,21& 22. fewest orders come in at 23,6,0,1,5,2,4 & 3

# %%
# creating categories
results_3 = []
for value in df_full["order_hour_of_day"]:
    if value in (10,11,14,15,13,12,16,9): 
        results_3.append("Most orders")
    elif value in (17,8,18,19,20,7,21,22):
        results_3.append("Average orders")
    else:
        results_3.append("Fewest orders")

# %%
# creating a new column for the 2nd new results categories
df_full['busiest_period_of_day'] = results_3

# %%
# checking frequency
df_full['busiest_period_of_day'].value_counts(dropna=False)
# Out:
# busiest_period_of_day
# Most orders       21118071
# Average orders     9997651
# Fewest orders      1289137
# Name: count, dtype: int64

# %%
df_full.to_pickle(os.path.join(path,'Prepared Data','Data Consistency','order_prods_merged_derived_values.pkl'))
